# %%
# Reading data feom GIT_HUB and saving it to folder
# aqi_2013 = pd.read_csv('https://raw.githubusercontent.com/krishnaik06/AQI-Project/master/Data/AQI/aqi2013.csv')
# aqi_2014 = pd.read_csv('https://raw.githubusercontent.com/krishnaik06/AQI-Project/master/Data/AQI/aqi2014.csv')
# aqi_2015 = pd.read_csv('https://raw.githubusercontent.com/krishnaik06/AQI-Project/master/Data/AQI/aqi2015.csv')
# aqi_2016 = pd.read_csv('https://raw.githubusercontent.com/krishnaik06/AQI-Project/master/Data/AQI/aqi2016.csv')
# aqi_2017 = pd.read_csv('https://raw.githubusercontent.com/krishnaik06/AQI-Project/master/Data/AQI/aqi2017.csv')
# aqi_2018 = pd.read_csv('https://raw.githubusercontent.com/krishnaik06/AQI-Project/master/Data/AQI/aqi2018.csv')


# Saving tha data
# aqi_2013.to_csv('aqi_data/aqi2013.csv', index=False)
# aqi_2014.to_csv('aqi_data/aqi2014.csv', index=False)
# aqi_2015.to_csv('aqi_data/aqi2015.csv', index=False)
# aqi_2016.to_csv('aqi_data/aqi2016.csv', index=False)
# aqi_2017.to_csv('aqi_data/aqi2017.csv', index=False)
# aqi_2018.to_csv('aqi_data/aqi2018.csv', index=False)

# %%
# Importing desired libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import sys

# %%
path, dirs, files=next(os.walk("/Users/PawanKumar/ML Notes/AQI Project/aqi_data"))
def avg_data2013():
    temp_i=0
    average2013=[]
    for rows in pd.read_csv('/Users/PawanKumar/ML Notes/AQI Project/aqi_data/aqi2013.csv', chunksize=24):
        add_var=0
        avg = 0.0
        data=[]
        df=pd.DataFrame(data= rows)
        for index, row in df.iterrows():
            data.append(row['PM2.5'])
        for i in data:
            if type(i) is float or type(i) is int :
                add_var+=i
            elif type(i) is str:
                if i !='NoData' and i!='PwrFail' and i!='Invld':
                    temp = float(i)
                    add_var+=temp
        avg= add_var/24
        temp_i+=1
        average2013.append(avg)
    return average2013
def avg_data2014():
    temp_i=0
    average2014=[]
    for rows in pd.read_csv('/Users/PawanKumar/ML Notes/AQI Project/aqi_data/aqi2014.csv', chunksize=24):
        add_var=0
        avg = 0.0
        data=[]
        df=pd.DataFrame(data= rows)
        for index, row in df.iterrows():
            data.append(row['PM2.5'])
        for i in data:
            if type(i) is float or type(i) is int :
                add_var+=i
            elif type(i) is str:
                if i !='NoData' and i!='PwrFail' and i!='Invld':
                    temp = float(i)
                    add_var+=temp
        avg= add_var/24
        temp_i+=1
        average2014.append(avg)
    return average2014
def avg_data2015():
    temp_i=0
    average2015=[]
    for rows in pd.read_csv('/Users/PawanKumar/ML Notes/AQI Project/aqi_data/aqi2015.csv', chunksize=24):
        add_var=0
        avg = 0.0
        data=[]
        df=pd.DataFrame(data= rows)
        for index, row in df.iterrows():
            data.append(row['PM2.5'])
        for i in data:
            if type(i) is float or type(i) is int :
                add_var+=i
            elif type(i) is str:
                if i !='NoData' and i!='PwrFail' and i!='InVld' and i!='---':
                    temp = float(i)
                    add_var+=temp
        avg= add_var/24
        temp_i+=1
        average2015.append(avg)
    return average2015
def avg_data2016():
    temp_i=0
    average2016=[]
    for rows in pd.read_csv('/Users/PawanKumar/ML Notes/AQI Project/aqi_data/aqi2016.csv', chunksize=24):
        add_var=0
        avg = 0.0
        data=[]
        df=pd.DataFrame(data= rows)
        for index, row in df.iterrows():
            data.append(row['PM2.5'])
        for i in data:
            if type(i) is float or type(i) is int :
                add_var+=i
            elif type(i) is str:
                if i !='NoData' and i!='PwrFail' and i!='InVld':
                    temp = float(i)
                    add_var+=temp
        avg= add_var/24
        temp_i+=1
        average2016.append(avg)
    return average2016
def avg_data2017():
    temp_i=0
    average2017=[]
    for rows in pd.read_csv('/Users/PawanKumar/ML Notes/AQI Project/aqi_data/aqi2017.csv', chunksize=24):
        add_var=0
        avg = 0.0
        data=[]
        df=pd.DataFrame(data= rows)
        for index, row in df.iterrows():
            data.append(row['PM2.5'])
        for i in data:
            if type(i) is float or type(i) is int :
                add_var+=i
            elif type(i) is str:
                if i !='NoData' and i!='PwrFail' and i!='Invld':
                    temp = float(i)
                    add_var+=temp
        avg= add_var/24
        temp_i+=1
        average2017.append(avg)
    return average2017
def avg_data2018():
    temp_i=0
    average2018=[]
    for rows in pd.read_csv('/Users/PawanKumar/ML Notes/AQI Project/aqi_data/aqi2018.csv', chunksize=24):
        add_var=0
        avg = 0.0
        data=[]
        df=pd.DataFrame(data= rows)
        for index, row in df.iterrows():
            data.append(row['PM2.5'])
        for i in data:
            if type(i) is float or type(i) is int :
                add_var+=i
            elif type(i) is str:
                if i !='NoData' and i!='PwrFail' and i!='Invld':
                    temp = float(i)
                    add_var+=temp
        avg= add_var/24
        temp_i+=1
        average2018.append(avg)
    return average2018
# def avg_data():
#     temp_i=0
#     average=[]
#     for rows in pd.read_csv('/Users/PawanKumar/ML Notes/AQI Project/aqi_data/aqi2013.csv', chunksize=24):
#         add_var=0
#         avg = 0.0
#         data=[]
#         df=pd.DataFrame(data= rows)
#         for index, row in df.iterrows():
#             data.append(row['PM2.5'])
#         for i in data:
#             if type(i) is float or type(i) is int :
#                 add_var+=i
#             elif type(i) is str:
#                 if i !='NoData' and i!='PwrFail' and i!='Invld':
#                     temp = float(i)
#                     add_var+=temp
#         avg= add_var/24
#         temp_i+=1
#         average.append(avg)
#     return average

if __name__=='__main__':
    avg2013=avg_data2013()
    avg2014=avg_data2014()
    avg2015=avg_data2015()
    avg2016=avg_data2016()
    avg2017=avg_data2017()
    avg2018=avg_data2018()
    plt.figure(figsize=(8,5))
    plt.plot(range(len(avg2013)), avg2013, label='2013-Data')
    plt.plot(range(len(avg2014)), avg2014, label='2014-Data')
    plt.plot(range(len(avg2015)), avg2015, label='2015-Data')
#     plt.plot(range(len(avg2016)), avg2016, label='2016-Data')
#     plt.plot(range(len(avg2017)), avg2017, label='2017-Data')
#     plt.plot(range(len(avg2018)), avg2018, label='2018-Data')
    plt.xlabel("Day")
    plt.legend()
    plt.ylabel('PM2.5')
    plt.show()
